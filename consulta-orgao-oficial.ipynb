# %%
pip install beautifulsoup4 requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests PyPDF2 pdfplumber
# Out:
# ...
#   Obtaining dependency information for pdfplumber from https://files.pythonhosted.org/packages/c1/f9/1a41afffe5e7a98ab9b6a6dd3dab9d99b677fae2536f676397c4506f6554/pdfplumber-0.10.2-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#       --------------------------------------- 0.1/5.6 MB 1.7 MB/s eta 0:00:04
#      - -------------------------------------- 0.2/5.6 MB 1.7 MB/s eta 0:00:04
#      -- ------------------------------------- 0.3/5.6 MB 2.0 MB/s eta 0:00:03
#      -- ------------------------------------- 0.4/5.6 MB 2.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.6/5.6 MB 2.5 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.7/5.6 MB 2.7 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.8/5.6 MB 2.5 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.8/5.6 MB 2.3 MB/s eta 0:00:03
# ...

# %%
import requests
import PyPDF2
import pdfplumber

# URL do PDF que você deseja baixar e consultar
pdf_url = "https://campomourao.atende.net/diariooficial/edicao"

# Função para baixar o PDF
def baixar_pdf(url):
    response = requests.get(url)
    if response.status_code == 200:
        with open("arquivo.pdf", 'wb') as file:
            file.write(response.content)
        return "arquivo.pdf"
    else:
        print("Não foi possível baixar o PDF.")
        return None

# Função para consultar o conteúdo do PDF usando PyPDF2
def consultar_pdf_com_pyPDF2(pdf_path):
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfFileReader(file)
        num_pages = pdf_reader.getNumPages()
        texto = ""
        for page_num in range(num_pages):
            page = pdf_reader.getPage(page_num)
            texto += page.extractText()
        return texto

# Função para consultar o conteúdo do PDF usando pdfplumber
def consultar_pdf_com_pdfplumber(pdf_path):
    texto = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            texto += page.extract_text()
    return texto

# Baixe o PDF
pdf_path = baixar_pdf(pdf_url)

if pdf_path:
    # Consulte o conteúdo do PDF com PyPDF2
    texto_pyPDF2 = consultar_pdf_com_pyPDF2(pdf_path)
    print("Conteúdo do PDF com PyPDF2:")
    print(texto_pyPDF2)

    # Consulte o conteúdo do PDF com pdfplumber
    texto_pdfplumber = consultar_pdf_com_pdfplumber(pdf_path)
    print("Conteúdo do PDF com pdfplumber:")
    print(texto_pdfplumber)
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# c:\Users\virgi\Workspace\GitHub\consulta-orgao-oficial\consulta-orgao-oficial.ipynb Célula 4 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/virgi/Workspace/GitHub/consulta-orgao-oficial/consulta-orgao-oficial.ipynb#W1sZmlsZQ%3D%3D?line=38'>39</a> pdf_path = baixar_pdf(pdf_url)
#      <a href='vscode-notebook-cell:/c%3A/Users/virgi/Workspace/GitHub/consulta-orgao-oficial/consulta-orgao-oficial.ipynb#W1sZmlsZQ%3D%3D?line=40'>41</a> if pdf_path:
#      <a href='vscode-notebook-cell:/c%3A/Users/virgi/Workspace/GitHub/consulta-orgao-oficial/consulta-orgao-oficial.ipynb#W1sZmlsZQ%3D%3D?line=41'>42</a>     # Consulte o conteúdo do PDF com PyPDF2
# ...
